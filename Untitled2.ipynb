# %%
import tensorflow as tf
from keras.models import Model
from keras.layers import Dense, Dropout, concatenate, LeakyReLU, ReLU
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, BatchNormalization, Activation,ZeroPadding2D,Flatten
from keras.layers import GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.layers import Reshape, add
from keras.utils import to_categorical
from keras.layers import ReLU
from keras import backend as K
from keras import optimizers


from keras.optimizers import Adam
import matplotlib.pyplot as plt
import sys
from tqdm import tqdm

import numpy as np

#opt = Adam(lr=0.001, beta_1=0.5, beta_2=0.999)
opt = Adam(learning_rate=0.001, beta_1=0.5, beta_2=0.999)

def residual_block(input):
    """
    Residual block in the generator network
    """
    x = Conv2D(128 * 4, kernel_size=(3, 3), padding='same', strides=1)(input)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv2D(128 * 4, kernel_size=(3, 3), strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    x = add([x, input])
    x = ReLU()(x)

    return x
img_shape = (256, 256, 3)

input_layer = Input(shape=(256, 256, 3))
x = ZeroPadding2D(padding=(1, 1))(input_layer)
x = Conv2D(128, kernel_size=(3, 3), strides=1, use_bias=False)(x)
x = ReLU()(x)

x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(256, kernel_size=(4, 4), strides=2, use_bias=False)(x)
x = BatchNormalization()(x)
x = ReLU()(x)

x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(512, kernel_size=(4, 4), strides=2, use_bias=False)(x)
x = BatchNormalization()(x)
x = ReLU()(x)

x = residual_block(x)
x = residual_block(x)
x=MaxPooling2D(pool_size=(2,2))(x)
x=Dropout(0.25)(x)#(x, training=True)

x = residual_block(x)
x = residual_block(x)

x=MaxPooling2D(pool_size=(2,2))(x)
x=Dropout(0.25)(x)#(x, training=True)
#x=Dropout(0.25)(x)
#x=GlobalAveragePooling2D()(x)
x=Flatten()(x)
x=Dense(128)(x)
x=ReLU()(x)

x = BatchNormalization(axis=-1)(x)
x = Dropout(0.5)(x)
output_layer=Dense(3, activation='softmax')(x)
model = Model(inputs=[input_layer], outputs=[output_layer])

#model.compile(loss='binary_crossentropy',optimizer=optimizers.RMSprop(),metrics=['binary_accuracy'])

model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 256, 256, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ zero_padding2d_3              │ (None, 258, 258, 3)       │               0 │ input_layer_1[0][0]        │
# │ (ZeroPadding2D)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_11 (Conv2D)            │ (None, 256, 256, 128)     │           3,456 │ zero_padding2d_3[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_12 (ReLU)               │ (None, 256, 256, 128)     │               0 │ conv2d_11[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ zero_padding2d_4              │ (None, 258, 258, 128)     │               0 │ re_lu_12[0][0]             │
# │ (ZeroPadding2D)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_12 (Conv2D)            │ (None, 128, 128, 256)     │         524,288 │ zero_padding2d_4[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 128, 128, 256)     │           1,024 │ conv2d_12[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_13 (ReLU)               │ (None, 128, 128, 256)     │               0 │ batch_normalization_11[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ zero_padding2d_5              │ (None, 130, 130, 256)     │               0 │ re_lu_13[0][0]             │
# │ (ZeroPadding2D)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_13 (Conv2D)            │ (None, 64, 64, 512)       │       2,097,152 │ zero_padding2d_5[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 64, 64, 512)       │           2,048 │ conv2d_13[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_14 (ReLU)               │ (None, 64, 64, 512)       │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_14 (Conv2D)            │ (None, 64, 64, 512)       │       2,359,808 │ re_lu_14[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 64, 64, 512)       │           2,048 │ conv2d_14[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_15 (ReLU)               │ (None, 64, 64, 512)       │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_15 (Conv2D)            │ (None, 64, 64, 512)       │       2,359,808 │ re_lu_15[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 64, 64, 512)       │           2,048 │ conv2d_15[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 64, 64, 512)       │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ re_lu_14[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_16 (ReLU)               │ (None, 64, 64, 512)       │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_16 (Conv2D)            │ (None, 64, 64, 512)       │       2,359,808 │ re_lu_16[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_15        │ (None, 64, 64, 512)       │           2,048 │ conv2d_16[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_17 (ReLU)               │ (None, 64, 64, 512)       │               0 │ batch_normalization_15[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_17 (Conv2D)            │ (None, 64, 64, 512)       │       2,359,808 │ re_lu_17[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_16        │ (None, 64, 64, 512)       │           2,048 │ conv2d_17[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_5 (Add)                   │ (None, 64, 64, 512)       │               0 │ batch_normalization_16[0]… │
# │                               │                           │                 │ re_lu_16[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_18 (ReLU)               │ (None, 64, 64, 512)       │               0 │ add_5[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 32, 32, 512)       │               0 │ re_lu_18[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 32, 32, 512)       │               0 │ max_pooling2d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_18 (Conv2D)            │ (None, 32, 32, 512)       │       2,359,808 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_17        │ (None, 32, 32, 512)       │           2,048 │ conv2d_18[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_19 (ReLU)               │ (None, 32, 32, 512)       │               0 │ batch_normalization_17[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_19 (Conv2D)            │ (None, 32, 32, 512)       │       2,359,808 │ re_lu_19[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_18        │ (None, 32, 32, 512)       │           2,048 │ conv2d_19[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_6 (Add)                   │ (None, 32, 32, 512)       │               0 │ batch_normalization_18[0]… │
# │                               │                           │                 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_20 (ReLU)               │ (None, 32, 32, 512)       │               0 │ add_6[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_20 (Conv2D)            │ (None, 32, 32, 512)       │       2,359,808 │ re_lu_20[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_19        │ (None, 32, 32, 512)       │           2,048 │ conv2d_20[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_21 (ReLU)               │ (None, 32, 32, 512)       │               0 │ batch_normalization_19[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_21 (Conv2D)            │ (None, 32, 32, 512)       │       2,359,808 │ re_lu_21[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_20        │ (None, 32, 32, 512)       │           2,048 │ conv2d_21[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_7 (Add)                   │ (None, 32, 32, 512)       │               0 │ batch_normalization_20[0]… │
# │                               │                           │                 │ re_lu_20[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_22 (ReLU)               │ (None, 32, 32, 512)       │               0 │ add_7[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 16, 16, 512)       │               0 │ re_lu_22[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 16, 16, 512)       │               0 │ max_pooling2d_3[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_1 (Flatten)           │ (None, 131072)            │               0 │ dropout_4[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 128)               │      16,777,344 │ flatten_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ re_lu_23 (ReLU)               │ (None, 128)               │               0 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_21        │ (None, 128)               │             512 │ re_lu_23[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 128)               │               0 │ batch_normalization_21[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 3)                 │             387 │ dropout_5[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 38,301,059 (146.11 MB)
#  Trainable params: 38,291,075 (146.07 MB)
#  Non-trainable params: 9,984 (39.00 KB)

# %%
model.load_weights('E:/AI/FYP_v2/potato_weights/wight1.weights.h5','E:/AI/FYP_v2/potato_weights/wight2.weights.h5')
# Out:
# C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\keras\src\saving\saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 92 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
BatchSize=32
ImageSize=256
Channel=3
Epochs=30

# %%
import tensorflow as tf

# Update the path to your dataset
directory = 'Test_data'

# Create a dataset
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    directory,
    image_size=(ImageSize, ImageSize),  # Resize images to 256x256
    batch_size=BatchSize          # Number of images to return in each batch
)

# # Display the first batch of images and labels
# for images, labels in dataset.take(1):
#     print(images.shape, labels.shape)
# Out:
# Found 450 files belonging to 3 classes.

# %%
class_names=test_dataset.class_names

# %%
class_names
# Out:
# ['Early_Blight', 'Healthy', 'Late_Blight']

# %%
score = model.evaluate(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 score = model.evaluate(dataset)
#
# NameError: name 'dataset' is not defined

# %%
import gradio as gr
import tensorflow as tf
import numpy as np
from PIL import Image

# Define the labels for your disease classes
labels = ['Early_Blight', 'Healthy', 'Late_Blight']

def predict_disease(image):
    # Convert the uploaded image to RGB and resize it to the input size expected by the model
    image = Image.fromarray(image)
    image = image.convert('RGB')
    image = image.resize((256, 256))
    image = np.array(image)

    # Normalize the image
    image = image / 255.0
    image = np.expand_dims(image, axis=0)  # Add batch dimension

    # Predict the disease
    predictions = model.predict(image)
    predicted_class = labels[np.argmax(predictions)]
    confidence_scores = {label: float(predictions[0][i]) for i, label in enumerate(labels)}

    return predicted_class, confidence_scores

# Create a Gradio interface
iface = gr.Interface(
    fn=predict_disease,
    inputs=gr.Image(),
    outputs=[gr.Textbox(label="Predicted Class"), gr.Label(label="Confidence Scores")],
    title="Potato Disease Identification (by: Pervez Abbas)"
)

# Launch the interface
iface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7862
#
# Thanks for being a Gradio user! If you have questions or feedback, please join our Discord server and chat with us: https://discord.gg/feTf9x3ZSB
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Exception in thread Thread-21 (_do_normal_analytics_request):
# Traceback (most recent call last):
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_transports\default.py", line 69, in map_httpcore_exceptions
#     yield
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_transports\default.py", line 233, in handle_request
#     resp = self._pool.handle_request(req)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection_pool.py", line 216, in handle_request
#     raise exc from None
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection_pool.py", line 196, in handle_request
#     response = connection.handle_request(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection.py", line 99, in handle_request
#     raise exc
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection.py", line 76, in handle_request
#     stream = self._connect(request)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection.py", line 122, in _connect
#     stream = self._network_backend.connect_tcp(**kwargs)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_backends\sync.py", line 205, in connect_tcp
#     with map_exceptions(exc_map):
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ConnectTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\gradio\analytics.py", line 70, in _do_normal_analytics_request
#     data["ip_address"] = get_local_ip_address()
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\gradio\analytics.py", line 131, in get_local_ip_address
#     ip_address = httpx.get(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_api.py", line 198, in get
#     return request(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_api.py", line 106, in request
#     return client.request(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 827, in request
#     return self.send(request, auth=auth, follow_redirects=follow_redirects)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 914, in send
#     response = self._send_handling_auth(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 1015, in _send_single_request
#     response = transport.handle_request(request)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_transports\default.py", line 232, in handle_request
#     with map_httpcore_exceptions():
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_transports\default.py", line 86, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectTimeout: timed out
# Exception in thread Thread-23 (_do_normal_analytics_request):
# Traceback (most recent call last):
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_transports\default.py", line 69, in map_httpcore_exceptions
#     yield
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_transports\default.py", line 233, in handle_request
#     resp = self._pool.handle_request(req)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection_pool.py", line 216, in handle_request
#     raise exc from None
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection_pool.py", line 196, in handle_request
#     response = connection.handle_request(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection.py", line 99, in handle_request
#     raise exc
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection.py", line 76, in handle_request
#     stream = self._connect(request)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_sync\connection.py", line 122, in _connect
#     stream = self._network_backend.connect_tcp(**kwargs)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_backends\sync.py", line 205, in connect_tcp
#     with map_exceptions(exc_map):
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ConnectTimeout: timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\threading.py", line 1016, in _bootstrap_inner
#     self.run()
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\threading.py", line 953, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\gradio\analytics.py", line 70, in _do_normal_analytics_request
#     data["ip_address"] = get_local_ip_address()
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\gradio\analytics.py", line 131, in get_local_ip_address
#     ip_address = httpx.get(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_api.py", line 198, in get
#     return request(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_api.py", line 106, in request
#     return client.request(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 827, in request
#     return self.send(request, auth=auth, follow_redirects=follow_redirects)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 914, in send
#     response = self._send_handling_auth(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_client.py", line 1015, in _send_single_request
#     response = transport.handle_request(request)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_transports\default.py", line 232, in handle_request
#     with map_httpcore_exceptions():
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\PERVEZ ABBAS\anaconda3\lib\site-packages\httpx\_transports\default.py", line 86, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectTimeout: timed out
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 18s 18s/step
